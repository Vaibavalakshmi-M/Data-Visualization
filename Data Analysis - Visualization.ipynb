# %%
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns

# %%
df=pd.read_csv('flight_dataset.csv')
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %%
df.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Date  Month  Year  \
# 0       IndiGo  Banglore   New Delhi            0   3897    24      3  2019
# 1    Air India   Kolkata    Banglore            2   7662     1      5  2019
# 2  Jet Airways     Delhi      Cochin            2  13882     9      6  2019
# 3       IndiGo   Kolkata    Banglore            1   6218    12      5  2019
# 4       IndiGo  Banglore   New Delhi            1  13302     1      3  2019
#
#    Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0         22       20              1           10               2
# 1          5       50             13           15               7
# 2          9       25              4           25              19
# 3         18        5             23           30               5
# 4         16       50             21           35               4
#
#    Duration_min
# 0            50
# 1            25
# 2             0
# 3            25
# 4            45

# %%
df.tail()
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min
# 10678            30
# 10679            35
# ...

# %%
df.dtypes
# Out:
# Airline           object
# Source            object
# Destination       object
# Total_Stops        int64
# Price              int64
# Date               int64
# Month              int64
# Year               int64
# Dep_hours          int64
# Dep_min            int64
# Arrival_hours      int64
# Arrival_min        int64
# Duration_hours     int64
# Duration_min       int64
# dtype: object

# %%
df.describe()
# Out:
#         Total_Stops         Price          Date         Month     Year  \
# count  10683.000000  10683.000000  10683.000000  10683.000000  10683.0
# mean       0.824207   9087.064121     13.508378      4.708602   2019.0
# std        0.675199   4611.359167      8.479277      1.164357      0.0
# min        0.000000   1759.000000      1.000000      3.000000   2019.0
# 25%        0.000000   5277.000000      6.000000      3.000000   2019.0
# 50%        1.000000   8372.000000     12.000000      5.000000   2019.0
# 75%        1.000000  12373.000000     21.000000      6.000000   2019.0
# max        4.000000  79512.000000     27.000000      6.000000   2019.0
#
#           Dep_hours       Dep_min  Arrival_hours   Arrival_min  \
# count  10683.000000  10683.000000   10683.000000  10683.000000
# mean      12.490686     24.411214      13.348778     24.690630
# std        5.748650     18.767980       6.859125     16.506036
# min        0.000000      0.000000       0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         10683 non-null  object
#  1   Source          10683 non-null  object
#  2   Destination     10683 non-null  object
#  3   Total_Stops     10683 non-null  int64
#  4   Price           10683 non-null  int64
#  5   Date            10683 non-null  int64
#  6   Month           10683 non-null  int64
#  7   Year            10683 non-null  int64
#  8   Dep_hours       10683 non-null  int64
#  9   Dep_min         10683 non-null  int64
#  10  Arrival_hours   10683 non-null  int64
#  11  Arrival_min     10683 non-null  int64
#  12  Duration_hours  10683 non-null  int64
#  13  Duration_min    10683 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.1+ MB

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['number']).columns

# %%
df[categorical_cols]
# Out:
#            Airline    Source Destination
# 0           IndiGo  Banglore   New Delhi
# 1        Air India   Kolkata    Banglore
# 2      Jet Airways     Delhi      Cochin
# 3           IndiGo   Kolkata    Banglore
# 4           IndiGo  Banglore   New Delhi
# ...            ...       ...         ...
# 10678     Air Asia   Kolkata    Banglore
# 10679    Air India   Kolkata    Banglore
# 10680  Jet Airways  Banglore       Delhi
# 10681      Vistara  Banglore   New Delhi
# 10682    Air India     Delhi      Cochin
#
# [10683 rows x 3 columns]

# %%
df[numerical_cols]
# Out:
#        Total_Stops  Price  Date  Month  Year  Dep_hours  Dep_min  \
# 0                0   3897    24      3  2019         22       20
# 1                2   7662     1      5  2019          5       50
# 2                2  13882     9      6  2019          9       25
# 3                1   6218    12      5  2019         18        5
# 4                1  13302     1      3  2019         16       50
# ...            ...    ...   ...    ...   ...        ...      ...
# 10678            0   4107     9      4  2019         19       55
# 10679            0   4145    27      4  2019         20       45
# 10680            0   7229    27      4  2019          8       20
# 10681            0  12648     1      3  2019         11       30
# 10682            2  11753     9      5  2019         10       55
#
#        Arrival_hours  Arrival_min  Duration_hours  Duration_min
# 0                  1           10               2            50
# ...

# %%
print("Categorical Data:\n", categorical_cols)
# Out:
# Categorical Data:
#  Index(['Airline', 'Source', 'Destination'], dtype='object')

# %%
print("\nNumerical Data:\n", numerical_cols)
# Out:
# Numerical Data:
#  Index(['Total_Stops', 'Price', 'Date', 'Month', 'Year', 'Dep_hours', 'Dep_min',
#        'Arrival_hours', 'Arrival_min', 'Duration_hours', 'Duration_min'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        Airline  Source  Destination  Total_Stops  Price   Date  Month   Year  \
# 0        False   False        False        False  False  False  False  False
# 1        False   False        False        False  False  False  False  False
# 2        False   False        False        False  False  False  False  False
# 3        False   False        False        False  False  False  False  False
# 4        False   False        False        False  False  False  False  False
# ...        ...     ...          ...          ...    ...    ...    ...    ...
# 10678    False   False        False        False  False  False  False  False
# 10679    False   False        False        False  False  False  False  False
# 10680    False   False        False        False  False  False  False  False
# 10681    False   False        False        False  False  False  False  False
# 10682    False   False        False        False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Airline           0
# Source            0
# Destination       0
# Total_Stops       0
# Price             0
# Date              0
# Month             0
# Year              0
# Dep_hours         0
# Dep_min           0
# Arrival_hours     0
# Arrival_min       0
# Duration_hours    0
# Duration_min      0
# dtype: int64

# %%
df.rename(columns={'Price':'Amount'})
# Out:
#            Airline    Source Destination  Total_Stops  Amount  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0    3897    24      3
# 1        Air India   Kolkata    Banglore            2    7662     1      5
# 2      Jet Airways     Delhi      Cochin            2   13882     9      6
# 3           IndiGo   Kolkata    Banglore            1    6218    12      5
# 4           IndiGo  Banglore   New Delhi            1   13302     1      3
# ...            ...       ...         ...          ...     ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0    4107     9      4
# 10679    Air India   Kolkata    Banglore            0    4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0    7229    27      4
# 10681      Vistara  Banglore   New Delhi            0   12648     1      3
# 10682    Air India     Delhi      Cochin            2   11753     9      5
#
# ...

# %%
df.drop(columns=['Airline'])
# Out:
#          Source Destination  Total_Stops  Price  Date  Month  Year  Dep_hours  \
# 0      Banglore   New Delhi            0   3897    24      3  2019         22
# 1       Kolkata    Banglore            2   7662     1      5  2019          5
# 2         Delhi      Cochin            2  13882     9      6  2019          9
# 3       Kolkata    Banglore            1   6218    12      5  2019         18
# 4      Banglore   New Delhi            1  13302     1      3  2019         16
# ...         ...         ...          ...    ...   ...    ...   ...        ...
# 10678   Kolkata    Banglore            0   4107     9      4  2019         19
# 10679   Kolkata    Banglore            0   4145    27      4  2019         20
# 10680  Banglore       Delhi            0   7229    27      4  2019          8
# 10681  Banglore   New Delhi            0  12648     1      3  2019         11
# 10682     Delhi      Cochin            2  11753     9      5  2019         10
#
# ...

# %%
df.query('Duration_hours > 10')
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 6      Jet Airways  Banglore   New Delhi            1  11087    12      3
# 7      Jet Airways  Banglore   New Delhi            1  22270     1      3
# 8      Jet Airways  Banglore   New Delhi            1  11087    12      3
# 10       Air India     Delhi      Cochin            1   8907     1      6
# ...            ...       ...         ...          ...    ...   ...    ...
# 10669    Air India     Delhi      Cochin            1   9929    15      6
# 10670    Air India   Kolkata    Banglore            2  11411    12      5
# 10672  Jet Airways     Delhi      Cochin            2  11150    27      6
# 10673  Jet Airways     Delhi      Cochin            2  16704    27      5
# 10674  Jet Airways  Banglore   New Delhi            1  11087    12      3
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %%
df.groupby('Dep_hours').agg({'Dep_min': 'count'})
# Out:
#            Dep_min
# Dep_hours
# 0               40
# 1               37
# 2              194
# 3               24
# 4              170
# 5              629
# 6              687
# 7              867
# 8              697
# 9              916
# 10             536
# 11             580
# 12             178
# 13             417
# 14             523
# 15             319
# 16             472
# 17             695
# 18             444
# 19             567
# 20             651
# 21             492
# 22             387
# 23             161

# %%
df.pivot_table(values='Dep_hours', index='Year', columns='Price')
# Out:
# Price  1759   1840   1965       2017   2050       2071       2175   2227   \
# Year
# 2019   17.75    2.0   15.0  14.057143   18.4  12.666667  14.428571  19.85
#
# Price      2228       2385   ...  35185  36235  36983  46490  52229  52285  \
# Year                         ...
# 2019   12.444444  10.333333  ...   18.0   14.0   12.0   20.0    5.0   20.0
#
# Price      54826  57209  62427  79512
# Year
# 2019   18.666667    9.0    5.0    5.0
#
# [1 rows x 1870 columns]

# %%
df.melt(id_vars=['Year'], value_vars=['Airline'])
# Out:
#        Year variable        value
# 0      2019  Airline       IndiGo
# 1      2019  Airline    Air India
# 2      2019  Airline  Jet Airways
# 3      2019  Airline       IndiGo
# 4      2019  Airline       IndiGo
# ...     ...      ...          ...
# 10678  2019  Airline     Air Asia
# 10679  2019  Airline    Air India
# 10680  2019  Airline  Jet Airways
# 10681  2019  Airline      Vistara
# 10682  2019  Airline    Air India
#
# [10683 rows x 3 columns]

# %%
df.apply(lambda x: x * 2, axis=1) #axis=1 - row | axis=0 - column
# Out:
#                       Airline            Source         Destination  \
# 0                IndiGoIndiGo  BangloreBanglore  New DelhiNew Delhi
# 1          Air IndiaAir India    KolkataKolkata    BangloreBanglore
# 2      Jet AirwaysJet Airways        DelhiDelhi        CochinCochin
# 3                IndiGoIndiGo    KolkataKolkata    BangloreBanglore
# 4                IndiGoIndiGo  BangloreBanglore  New DelhiNew Delhi
# ...                       ...               ...                 ...
# 10678        Air AsiaAir Asia    KolkataKolkata    BangloreBanglore
# 10679      Air IndiaAir India    KolkataKolkata    BangloreBanglore
# 10680  Jet AirwaysJet Airways  BangloreBanglore          DelhiDelhi
# 10681          VistaraVistara  BangloreBanglore  New DelhiNew Delhi
# 10682      Air IndiaAir India        DelhiDelhi        CochinCochin
#
#        Total_Stops  Price  Date  Month  Year  Dep_hours  Dep_min  \
# 0                0   7794    48      6  4038         44       40
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['year'] = df['Date'].dt.year

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi            0   3897
# 1        Air India   Kolkata    Banglore            2   7662
# 2      Jet Airways     Delhi      Cochin            2  13882
# 3           IndiGo   Kolkata    Banglore            1   6218
# 4           IndiGo  Banglore   New Delhi            1  13302
# ...            ...       ...         ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107
# 10679    Air India   Kolkata    Banglore            0   4145
# 10680  Jet Airways  Banglore       Delhi            0   7229
# 10681      Vistara  Banglore   New Delhi            0  12648
# 10682    Air India     Delhi      Cochin            2  11753
#
#                                Date  Month  Year  Dep_hours  Dep_min  \
# 0     1970-01-01 00:00:00.000000024      3  2019         22       20
# 1     1970-01-01 00:00:00.000000001      5  2019          5       50
# ...

# %%
df['Year'].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['Price','Year'])
# Out:
# <Axes: >

# %%
df.plot.scatter(x='Year',y='Price')
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df['Airline'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Airline'>

# %%
mp.figure(figsize=(8,8))
sns.heatmap(df[numerical_cols].corr(),annot=True)
mp.show()

# %%
df['Airline'].value_counts().plot.pie(autopct='%1.1f%%',
                                      startangle=90,
                                      pctdistance=0.65,
                                      labeldistance=1.5)
mp.figure(figsize=(10, 8))

# %%
sns.violinplot(x='Source', y='Price', data=df)
# Out:
# <Axes: xlabel='Source', ylabel='Price'>

# %%
sns.pairplot(df)

# %%
sns.stripplot(x='Source', y='Price', data=df, jitter=True)
# Out:
# <Axes: xlabel='Source', ylabel='Price'>
